# %% [markdown]
# ### Importing Important Libraries
#
# The first and most important step is to import the libraries you will be using.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import joblib

# %% [markdown]
# ### Exploring the data

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head(n=10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %% [markdown]
# This gives us an idea about the data as to how much columns are there, and if any categorical values are there.
# This dataset is divided into males and females and their information regarding annual income and their spending behaviours.
#
#
# ### Checking size of data

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# There are 200 customers with 5 feature in data.

# %% [markdown]
# ### Checking data types of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
# CustomerID                200 non-null int64
# Genre                     200 non-null object
# Age                       200 non-null int64
# Annual Income (k$)        200 non-null int64
# Spending Score (1-100)    200 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ### Renaming the columns

# %%
df = df.rename(columns={'Annual Income (k$)': 'Annual_income', 'Spending Score (1-100)': 'Spending_score','Genre':'Gender'})

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual_income  Spending_score
# 0           1    Male   19             15              39
# 1           2    Male   21             15              81
# 2           3  Female   20             16               6
# 3           4  Female   23             16              77
# 4           5  Female   31             17              40

# %% [markdown]
# ### Removing CustomerId column
#
# Since this feature has no impact on beaviour of customers, we can discard this column

# %%
df.drop('CustomerID',axis=1,inplace=True)
df.head()
# Out:
#    Gender  Age  Annual_income  Spending_score
# 0    Male   19             15              39
# 1    Male   21             15              81
# 2  Female   20             16               6
# 3  Female   23             16              77
# 4  Female   31             17              40

# %%
df['Gender'].replace(['Female','Male'], [0,1],inplace=True)

# %% [markdown]
# We have replaced Female with zero and Male with one to make the data ready for our clustering model to use.
#
#
# ### Checking Null values

# %%
df.isnull().sum()
# Out:
# Gender            0
# Age               0
# Annual_income     0
# Spending_score    0
# dtype: int64

# %% [markdown]
# If any of the sum is non zero we can remove null values or replace null values with mean depending on amount of null data.

# %% [markdown]
# # EDA with Data Visualizations
#
#
# EDA is a process of performing initial investigations on data so as to draw raw conclusions, discover patterns and spot outliers. We check hypothesis etc using visualization tools.
#
# Data visualization is the graphical representaion of data which helps us to get better insight by plotting all the data collectively.
#
#
# We will now try to get better insight of data using matplotlib and seaborn library.

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### Counting the number of Males and Females

# %%
sns.countplot(x='Gender',data=df,palette="twilight_r")

# %% [markdown]
# It can be clearly seen that there are more females customer as compared to male customers i.e. around 85 males and more than 100 females.

# %%
plt.figure(1 , figsize = (15 , 6))
feature_list = ['Age','Annual_income', "Spending_score"]
feature_listt = ['Age','Annual_income', "Spending_score"]
pos = 1 
for i in feature_list:
    plt.subplot(1 , 3 , pos)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.distplot(df[i], bins=20, kde = True,color="Black")
    pos = pos + 1
plt.show()

# %% [markdown]
# The above plot helps in realizing the distribution of data for different features. It can be seen that while most of the data represents gaussian distribution there are some extremas and outliers too. To better visualize the outliers we can use box plot.

# %%
sns.boxplot(data=df,orient='h',palette='rainbow_r')

# %% [markdown]
# - It can be reported that an outlier exists in "ANNUAL INCOME" feature.
# - Average age of customers lies between 30 and 40.
# - Average spending score of customers is almost 50.
# - Average annual income is 60k$

# %%
sns.pairplot(df,  kind ="reg", hue = "Gender", palette="twilight")
plt.tight_layout()

# %% [markdown]
# The above pairplot graphic gives relation between different features while making a difference between genders. It can be seen that there is a relation between age, annual income, and spending score. We will visualize this more clearly in next scetions.

# %% [markdown]
# ### Age VS Spending score
#
#
# The below plot indicates that spending score is decreasing with age.
# Spending score is higher with age between 20 to 40

# %%
sns.lmplot(x = "Age", y = "Spending_score", data = df, hue = "Gender",palette="rainbow_r")

# %% [markdown]
# ### Annual Income VS Spending score
#
#
# The plot between annual income and spending score indicates that:
# - Spending score is saturated at 40 to 60 for values of income between 40 to 70.
# - There is no significant difference between male and female spendings.

# %%
sns.lmplot(x = "Annual_income", y = "Spending_score", data = df, hue = "Gender",palette="plasma")

# %% [markdown]
# ### Annual Income VS Age
#
# The following plot indicates that:
#
# - Anuual income is fair enough for people between ages 30 to 40

# %%
sns.lmplot(y = "Annual_income", x = "Age", data = df, hue = "Gender",palette="cool")

# %% [markdown]
#     Now it's time to save our pre-processed data for later use.

# %%
joblib.dump((df),"mallcustomers_preprocessed.pkl", compress=3)
# Out:
# ['mallcustomers_preprocessed.pkl']
